# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data
# https://fred.stlouisfed.org/series/S4248SM144NCEN

# %%
df = pd.read_csv("C:/Users/paras/Downloads/Alcohol_Sales-1.csv",index_col='DATE',parse_dates=True)
df.index.freq = 'MS'

# %%
df.head()
# Out:
#             S4248SM144NCEN
# DATE
# 1992-01-01            3459
# 1992-02-01            3458
# 1992-03-01            4002
# 1992-04-01            4564
# 1992-05-01            4221

# %%
df.columns = ['Sales']

# %%
df.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='DATE'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
results = seasonal_decompose(df['Sales'])
results.observed.plot(figsize=(12,2))
# Out:
# <Axes: xlabel='DATE'>

# %%
results.trend.plot(figsize=(12,2))
# Out:
# <Axes: xlabel='DATE'>

# %%
results.seasonal.plot(figsize=(12,2))
# Out:
# <Axes: xlabel='DATE'>

# %%
results.resid.plot(figsize=(12,2))
# Out:
# <Axes: xlabel='DATE'>

# %% [markdown]
# ## Train Test Split

# %%
len(df)
# Out:
# 340

# %%
325-12
# Out:
# 313

# %%
train = df.iloc[:313]
test = df.iloc[313:]

# %%
len(test)
# Out:
# 27

# %% [markdown]
# ## Scale Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
# IGNORE WARNING ITS JUST CONVERTING TO FLOATS
# WE ONLY FIT TO TRAININ DATA, OTHERWISE WE ARE CHEATING ASSUMING INFO ABOUT TEST SET
scaler.fit(train)
# Out:
# MinMaxScaler()

# %%
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %% [markdown]
# # Time Series Generator
#
# This class takes in a sequence of data-points gathered at
# equal intervals, along with time series parameters such as
# stride, length of history, etc., to produce batches for
# training/validation.
#
# #### Arguments
#     data: Indexable generator (such as list or Numpy array)
#         containing consecutive data points (timesteps).
#         The data should be at 2D, and axis 0 is expected
#         to be the time dimension.
#     targets: Targets corresponding to timesteps in `data`.
#         It should have same length as `data`.
#     length: Length of the output sequences (in number of timesteps).
#     sampling_rate: Period between successive individual timesteps
#         within sequences. For rate `r`, timesteps
#         `data[i]`, `data[i-r]`, ... `data[i - length]`
#         are used for create a sample sequence.
#     stride: Period between successive output sequences.
#         For stride `s`, consecutive output samples would
#         be centered around `data[i]`, `data[i+s]`, `data[i+2*s]`, etc.
#     start_index: Data points earlier than `start_index` will not be used
#         in the output sequences. This is useful to reserve part of the
#         data for test or validation.
#     end_index: Data points later than `end_index` will not be used
#         in the output sequences. This is useful to reserve part of the
#         data for test or validation.
#     shuffle: Whether to shuffle output samples,
#         or instead draw them in chronological order.
#     reverse: Boolean: if `true`, timesteps in each output sample will be
#         in reverse chronological order.
#     batch_size: Number of timeseries samples in each batch
#         (except maybe the last one).

# %%
# from keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
scaled_train
# Out:
# array([[0.03662502],
#        [0.03653945],
#        [0.08309088],
#        [0.13118261],
#        [0.10183125],
#        [0.12818757],
#        [0.12279651],
#        [0.09464316],
#        [0.09370187],
#        [0.10508301],
#        [0.10345713],
#        [0.16301557],
#        [0.        ],
#        [0.01968167],
#        [0.09661133],
#        [0.11518056],
#        [0.10919048],
#        [0.14247818],
#        [0.12211193],
#        [0.12202636],
#        [0.11406812],
#        [0.10311484],
#        [0.12570597],
#        [0.16626733],
#        [0.00376519],
#        [0.02960808],
#        [0.12082834],
#        [0.10525415],
#        [0.12228307],
#        [0.16720863],
#        [0.11064522],
#        [0.14444635],
#        [0.11492384],
#        [0.10414171],
#        [0.15000856],
#        [0.16601061],
#        [0.02900907],
#        [0.03876433],
#        [0.10593873],
#        [0.0824063 ],
#        [0.14410406],
#        [0.16626733],
#        [0.1020024 ],
#        [0.16849221],
#        [0.10302927],
#        [0.13032689],
#        [0.15574191],
#        [0.1536026 ],
#        [0.05716242],
#        [0.081465  ],
#        [0.10533972],
#        [0.1358891 ],
#        [0.18723259],
#        [0.15445833],
#        [0.16344344],
#        [0.17379771],
#        [0.11415369],
#        [0.16951908],
#        [0.15565634],
#        [0.17679274],
#        [0.06221119],
#        [0.06794455],
#        [0.12176964],
#        [0.13725826],
#        [0.18646243],
#        [0.17336984],
#        [0.18825946],
#        [0.17140168],
#        [0.16592504],
#        [0.197758  ],
#        [0.15403046],
#        [0.25106966],
#        [0.06546295],
#        [0.08454561],
#        [0.15976382],
#        [0.17619374],
#        [0.18877289],
#        [0.20674311],
#        [0.20571624],
#        [0.17764847],
#        [0.21256204],
#        [0.21838097],
#        [0.19810029],
#        [0.27853842],
#        [0.08565805],
#        [0.12014376],
#        [0.20948143],
#        [0.20982372],
#        [0.21872326],
#        [0.26912545],
#        [0.22163272],
#        [0.24456615],
#        [0.23934623],
#        [0.24114325],
#        [0.26946774],
#        [0.32004107],
#        [0.10371385],
#        [0.16438473],
#        [0.25474927],
#        [0.1986993 ],
#        [0.29128872],
#        [0.31165497],
#        [0.22291631],
#        [0.30797536],
#        [0.244395  ],
#        [0.28161903],
#        [0.45901078],
#        [0.50119801],
#        [0.60576759],
#        [0.63854184],
#        [0.78615437],
#        [0.7148725 ],
#        [0.69784357],
#        [0.72146158],
#        [0.63862742],
#        [0.72813623],
#        [0.69373609],
#        [0.82817046],
#        [0.47287352],
#        [0.51583091],
#        [0.6010611 ],
#        [0.67995893],
#        [0.7497005 ],
#        [0.75928461],
#        [0.67893206],
#        [0.68030122],
#        [0.66720863],
#        [0.75183981],
#        [0.63657368],
#        [0.87959952],
#        [0.45943864],
#        [0.51608763],
#        [0.65813794],
#        [0.69108335],
#        [0.72539791],
#        [0.84485709],
#        [0.75628958],
#        [0.70109533],
#        [0.76938217],
#        [0.76604484],
#        [0.72522677],
#        [0.9543043 ],
#        [0.48083176],
#        [0.6240801 ],
#        [0.77682697],
#        [0.71812425],
#        [0.78820811],
#        [0.9116892 ],
#        [0.67807633],
#        [0.82782817],
#        [0.79111758],
#        [0.75979805],
#        [0.85486907],
#        [0.97501284],
#        [0.51463289],
#        [0.63511895],
#        [0.80865993],
#        [0.72377203],
#        [0.89902447],
#        [1.        ],
#        [0.71572822],
#        [0.88499059],
#        [0.75646072],
#        [0.82423413],
#        [0.87035769],
#        [0.95498888],
#        [0.55296937]])

# %%
# define generator
n_input = 2
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
len(scaled_train)
# Out:
# 313

# %%
len(generator) # n_input = 2
# Out:
# 311

# %%
scaled_train
# Out:
# array([[0.03662502],
#        [0.03653945],
#        [0.08309088],
#        [0.13118261],
#        [0.10183125],
#        [0.12818757],
#        [0.12279651],
#        [0.09464316],
#        [0.09370187],
#        [0.10508301],
#        [0.10345713],
#        [0.16301557],
#        [0.        ],
#        [0.01968167],
#        [0.09661133],
#        [0.11518056],
#        [0.10919048],
#        [0.14247818],
#        [0.12211193],
#        [0.12202636],
#        [0.11406812],
#        [0.10311484],
#        [0.12570597],
#        [0.16626733],
#        [0.00376519],
#        [0.02960808],
#        [0.12082834],
#        [0.10525415],
#        [0.12228307],
#        [0.16720863],
#        [0.11064522],
#        [0.14444635],
#        [0.11492384],
#        [0.10414171],
#        [0.15000856],
#        [0.16601061],
#        [0.02900907],
#        [0.03876433],
#        [0.10593873],
#        [0.0824063 ],
#        [0.14410406],
#        [0.16626733],
#        [0.1020024 ],
#        [0.16849221],
#        [0.10302927],
#        [0.13032689],
#        [0.15574191],
#        [0.1536026 ],
#        [0.05716242],
#        [0.081465  ],
#        [0.10533972],
#        [0.1358891 ],
#        [0.18723259],
#        [0.15445833],
#        [0.16344344],
#        [0.17379771],
#        [0.11415369],
#        [0.16951908],
#        [0.15565634],
#        [0.17679274],
#        [0.06221119],
#        [0.06794455],
#        [0.12176964],
#        [0.13725826],
#        [0.18646243],
#        [0.17336984],
#        [0.18825946],
#        [0.17140168],
#        [0.16592504],
#        [0.197758  ],
#        [0.15403046],
#        [0.25106966],
#        [0.06546295],
#        [0.08454561],
#        [0.15976382],
#        [0.17619374],
#        [0.18877289],
#        [0.53414342],
#        [0.54672257],
#        [0.54612357],
#        [0.5848879 ],
#        [0.72086257],
#        [0.3311655 ],
#        [0.42640767],
#        [0.58197844],
#        [0.534828  ],
#        [0.59353072],
#        [0.71136403],
#        [0.51985282],
#        [0.63648811],
#        [0.60362827],
#        [0.56315249],
#        [0.62442239],
#        [0.7232586 ],
#        [0.3812254 ],
#        [0.48006161],
#        [0.57145302],
#        [0.54697929],
#        [0.71119288],
#        [0.70537395],
#        [0.58309088],
#        [0.69587541],
#        [0.55630669],
#        [0.66087626],
#        [0.67790519],
#        [0.76082492],
#        [0.45901078],
#        [0.50119801],
#        [0.60576759],
#        [0.63854184],
#        [0.78615437],
#        [0.7148725 ],
#        [0.69784357],
#        [0.72146158],
#        [0.63862742],
#        [0.72813623],
#        [0.69373609],
#        [0.82817046],
#        [0.47287352],
#        [0.51583091],
#        [0.6010611 ],
#        [0.67995893],
#        [0.7497005 ],
#        [0.75928461],
#        [0.67893206],
#        [0.68030122],
#        [0.66720863],
#        [0.75183981],
#        [0.63657368],
#        [0.87959952],
#        [0.45943864],
#        [0.51608763],
#        [0.65813794],
#        [0.69108335],
#        [0.72539791],
#        [0.84485709],
#        [0.75628958],
#        [0.70109533],
#        [0.76938217],
#        [0.76604484],
#        [0.72522677],
#        [0.9543043 ],
#        [0.48083176],
#        [0.6240801 ],
#        [0.77682697],
#        [0.71812425],
#        [0.78820811],
#        [0.9116892 ],
#        [0.67807633],
#        [0.82782817],
#        [0.79111758],
#        [0.75979805],
#        [0.85486907],
#        [0.97501284],
#        [0.51463289],
#        [0.63511895],
#        [0.80865993],
#        [0.72377203],
#        [0.89902447],
#        [1.        ],
#        [0.71572822],
#        [0.88499059],
#        [0.75646072],
#        [0.82423413],
#        [0.87035769],
#        [0.95498888],
#        [0.55296937]])

# %%
# What does the first batch look like?
X,y = generator[0]

# %%
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.03662502 0.03653945]
# Predict this y:
#  [[0.08309088]]

# %%
# Let's redefine to get 12 months back and then predict the next month out
n_input = 12
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
# What does the first batch look like?
X,y = generator[0]

# %%
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.03662502 0.03653945 0.08309088 0.13118261 0.10183125 0.12818757
#  0.12279651 0.09464316 0.09370187 0.10508301 0.10345713 0.16301557]
# Predict this y:
#  [[0.]]

# %% [markdown]
# ### Create the Model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# define model
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# Out:
# C:\Users\paras\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100)                 │          40,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │             101 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 40,901 (159.77 KB)
#  Trainable params: 40,901 (159.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# %%time
# fit model
model.fit(generator,epochs=50)
# Out:
# Epoch 1/50
# C:\Users\paras\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 0.0380
# Epoch 2/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0092
# Epoch 3/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0107
# Epoch 4/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0087
# Epoch 5/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0105
# Epoch 6/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0080
# Epoch 7/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0064
# Epoch 8/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0070
# Epoch 9/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0049
# Epoch 10/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0041
# Epoch 11/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0048
# Epoch 12/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0029
# Epoch 13/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0023
# Epoch 14/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0023
# Epoch 15/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0016
# Epoch 16/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0023
# Epoch 17/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0018
# Epoch 18/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0019
# Epoch 19/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0026
# Epoch 20/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0019
# Epoch 21/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0018
# Epoch 22/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0015
# Epoch 23/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0015
# Epoch 24/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0019
# Epoch 25/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0019
# Epoch 26/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0015
# Epoch 27/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0015
# Epoch 28/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0016
# Epoch 29/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0015
# Epoch 30/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0017
# Epoch 31/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0017
# Epoch 32/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0015
# Epoch 33/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0016
# Epoch 34/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0012
# Epoch 35/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0024
# Epoch 36/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0020
# Epoch 37/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0013
# Epoch 38/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0013
# Epoch 39/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0016
# Epoch 40/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0014
# Epoch 41/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0014
# Epoch 42/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0015
# Epoch 43/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0013
# Epoch 44/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0013
# Epoch 45/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0016
# Epoch 46/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0016
# Epoch 47/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0014
# Epoch 48/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0013
# Epoch 49/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0015
# Epoch 50/50
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 0.0015
# CPU times: total: 6min 25s
# Wall time: 3min 7s

# %%
model.history.history.keys()
# Out:
# dict_keys(['loss'])

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %% [markdown]
# ## Evaluate on Test Data

# %%
first_eval_batch = scaled_train[-12:]

# %%
first_eval_batch
# Out:
# array([[0.63511895],
#        [0.80865993],
#        [0.72377203],
#        [0.89902447],
#        [1.        ],
#        [0.71572822],
#        [0.88499059],
#        [0.75646072],
#        [0.82423413],
#        [0.87035769],
#        [0.95498888],
#        [0.55296937]])

# %%
first_eval_batch = first_eval_batch.reshape((1, n_input, n_features))

# %%
model.predict(first_eval_batch)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 617ms/step
# array([[0.67684823]], dtype=float32)

# %%
scaled_test[0]
# Out:
# array([0.62450796])

# %% [markdown]
# Now let's put this logic in a for loop to predict into the future for the entire test range.
#
# ----

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

# %%
current_batch.shape
# Out:
# (1, 12, 1)

# %%
current_batch
# Out:
# array([[[0.63511895],
#         [0.80865993],
#         [0.72377203],
#         [0.89902447],
#         [1.        ],
#         [0.71572822],
#         [0.88499059],
#         [0.75646072],
#         [0.82423413],
#         [0.87035769],
#         [0.95498888],
#         [0.55296937]]])

# %%
np.append(current_batch[:,1:,:],[[[99]]],axis=1)
# Out:
# array([[[ 0.80865993],
#         [ 0.72377203],
#         [ 0.89902447],
#         [ 1.        ],
#         [ 0.71572822],
#         [ 0.88499059],
#         [ 0.75646072],
#         [ 0.82423413],
#         [ 0.87035769],
#         [ 0.95498888],
#         [ 0.55296937],
#         [99.        ]]])

# %% [markdown]
# **NOTE: PAY CLOSE ATTENTION HERE TO WHAT IS BEING OUTPUTED AND IN WHAT DIMENSIONS. ADD YOUR OWN PRINT() STATEMENTS TO SEE WHAT IS TRULY GOING ON!!**

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    test_predictions.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step

# %%
test_predictions
# Out:
# [array([0.67684823], dtype=float32),
#  array([0.79184103], dtype=float32),
#  array([0.74184185], dtype=float32),
#  array([0.8931503], dtype=float32),
#  array([0.97024506], dtype=float32),
#  array([0.73465574], dtype=float32),
#  array([0.8833178], dtype=float32),
#  array([0.75194484], dtype=float32),
#  array([0.8268453], dtype=float32),
#  array([0.8580882], dtype=float32),
#  array([0.94105643], dtype=float32),
#  array([0.54973465], dtype=float32),
#  array([0.70193636], dtype=float32),
#  array([0.77465594], dtype=float32),
#  array([0.75328505], dtype=float32),
#  array([0.88345814], dtype=float32),
#  array([0.9445957], dtype=float32),
#  array([0.74622864], dtype=float32),
#  array([0.8798969], dtype=float32),
#  array([0.7490221], dtype=float32),
#  array([0.82758594], dtype=float32),
#  array([0.846586], dtype=float32),
#  array([0.92854375], dtype=float32),
#  array([0.5559531], dtype=float32),
#  array([0.721086], dtype=float32),
#  array([0.7581837], dtype=float32),
#  array([0.75933087], dtype=float32)]

# %%
scaled_test
# Out:
# array([[0.62450796],
#        [0.81619031],
#        [0.75081294],
#        [0.9396714 ],
#        [0.97458497],
#        [0.81182612],
#        [0.94489132],
#        [0.78726681],
#        [0.91528324],
#        [0.93428034],
#        [1.05057334],
#        [0.64906726],
#        [0.67987335],
#        [0.80788978],
#        [0.86145816],
#        [0.98767756],
#        [0.96234811],
#        [0.89448913],
#        [0.95618689],
#        [0.85238747],
#        [0.97518398],
#        [0.91921958],
#        [1.12664727],
#        [0.65274688],
#        [0.71187746],
#        [0.88815677],
#        [0.79984597]])

# %% [markdown]
# ## Inverse Transformations and Compare

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
true_predictions
# Out:
# array([[10940.64844787],
#        [12284.45427799],
#        [11700.16389024],
#        [13468.35475159],
#        [14369.28380978],
#        [11616.18695283],
#        [13353.45214009],
#        [11818.22739971],
#        [12693.5140388 ],
#        [13058.61865056],
#        [14028.18544495],
#        [ 9455.19914377],
#        [11233.82835174],
#        [12083.6292932 ],
#        [11833.88909888],
#        [13355.09179497],
#        [14069.54528642],
#        [11751.42783225],
#        [13313.47493029],
#        [11784.07256675],
#        [12702.16924334],
#        [12924.20386744],
#        [13881.96222126],
#        [ 9527.86775625],
#        [11457.61129093],
#        [11891.13492537],
#        [11904.54053187]])

# %%
test
# Out:
#             Sales
# DATE
# 2018-02-01  10329
# 2018-03-01  12569
# 2018-04-01  11805
# 2018-05-01  14012
# 2018-06-01  14420
# 2018-07-01  12518
# 2018-08-01  14073
# 2018-09-01  12231
# 2018-10-01  13727
# 2018-11-01  13949
# 2018-12-01  15308
# 2019-01-01  10616
# 2019-02-01  10976
# 2019-03-01  12472
# 2019-04-01  13098
# 2019-05-01  14573
# 2019-06-01  14277
# 2019-07-01  13484
# 2019-08-01  14205
# 2019-09-01  12992
# 2019-10-01  14427
# 2019-11-01  13773
# 2019-12-01  16197
# 2020-01-01  10659
# 2020-02-01  11350
# 2020-03-01  13410
# 2020-04-01  12378

# %%
# IGNORE WARNINGS
test['Predictions'] = true_predictions
# Out:
# C:\Users\paras\AppData\Local\Temp\ipykernel_25520\1339453577.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions

# %%
test
# Out:
#             Sales   Predictions
# DATE
# 2018-02-01  10329  10940.648448
# 2018-03-01  12569  12284.454278
# 2018-04-01  11805  11700.163890
# 2018-05-01  14012  13468.354752
# 2018-06-01  14420  14369.283810
# 2018-07-01  12518  11616.186953
# 2018-08-01  14073  13353.452140
# 2018-09-01  12231  11818.227400
# 2018-10-01  13727  12693.514039
# 2018-11-01  13949  13058.618651
# 2018-12-01  15308  14028.185445
# 2019-01-01  10616   9455.199144
# 2019-02-01  10976  11233.828352
# 2019-03-01  12472  12083.629293
# 2019-04-01  13098  11833.889099
# 2019-05-01  14573  13355.091795
# 2019-06-01  14277  14069.545286
# 2019-07-01  13484  11751.427832
# 2019-08-01  14205  13313.474930
# 2019-09-01  12992  11784.072567
# 2019-10-01  14427  12702.169243
# 2019-11-01  13773  12924.203867
# 2019-12-01  16197  13881.962221
# 2020-01-01  10659   9527.867756
# 2020-02-01  11350  11457.611291
# 2020-03-01  13410  11891.134925
# 2020-04-01  12378  11904.540532

# %%
test.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='DATE'>

# %% [markdown]
# # Saving and Loading Models

# %%
model.save('my_rnn_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## load a model

# %%
from keras.models import load_model
new_model = load_model('my_rnn_model.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 2
#       1 from keras.models import load_model
# ----> 2 new_model = load_model('my_rnn_model.h5')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
#     200     raise ValueError(
#     201         f"File not found: filepath={filepath}. "
#     202         "Please ensure the file is an accessible `.keras` "
#     203         "zip file."
#     204     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:155, in load_model_from_hdf5(filepath, custom_objects, compile)
#     151 training_config = json_utils.decode(training_config)
#     153 # Compile model.
#     154 model.compile(
# --> 155     **saving_utils.compile_args_from_training_config(
#     156         training_config, custom_objects
#     157     )
#     158 )
#     159 saving_utils.try_build_compiled_arguments(model)
#     161 # Set optimizer weights.
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:143, in compile_args_from_training_config(training_config, custom_objects)
#     141 loss_config = training_config.get("loss", None)
#     142 if loss_config is not None:
# --> 143     loss = _deserialize_nested_config(losses.deserialize, loss_config)
#     144     # Ensure backwards compatibility for losses in legacy H5 files
#     145     loss = _resolve_compile_arguments_compat(loss, loss_config, losses)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:202, in _deserialize_nested_config(deserialize_fn, config)
#     200     return None
#     201 if _is_single_object(config):
# --> 202     return deserialize_fn(config)
#     203 elif isinstance(config, dict):
#     204     return {
#     205         k: _deserialize_nested_config(deserialize_fn, v)
#     206         for k, v in config.items()
#     207     }
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses\__init__.py:155, in deserialize(name, custom_objects)
#     142 @keras_export("keras.losses.deserialize")
#     143 def deserialize(name, custom_objects=None):
#     144     """Deserializes a serialized loss class/function instance.
#     145
#     146     Args:
#    (...)
#     153         A Keras `Loss` instance or a loss function.
#     154     """
# --> 155     return serialization_lib.deserialize_keras_object(
#     156         name,
#     157         module_objects=ALL_OBJECTS_DICT,
#     158         custom_objects=custom_objects,
#     159     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\saving\serialization_lib.py:575, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     573             return config
#     574         if isinstance(module_objects[config], types.FunctionType):
# --> 575             return deserialize_keras_object(
#     576                 serialize_with_public_fn(
#     577                     module_objects[config], config, fn_module_name
#     578                 ),
#     579                 custom_objects=custom_objects,
#     580             )
#     581         return deserialize_keras_object(
#     582             serialize_with_public_class(
#     583                 module_objects[config], inner_config=inner_config
#     584             ),
#     585             custom_objects=custom_objects,
#     586         )
#     588 if isinstance(config, PLAIN_TYPES):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\saving\serialization_lib.py:678, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     676 if class_name == "function":
#     677     fn_name = inner_config
# --> 678     return _retrieve_class_or_fn(
#     679         fn_name,
#     680         registered_name,
#     681         module,
#     682         obj_type="function",
#     683         full_config=config,
#     684         custom_objects=custom_objects,
#     685     )
#     687 # Below, handling of all classes.
#     688 # First, is it a shared object?
#     689 if "shared_object_id" in config:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\saving\serialization_lib.py:803, in _retrieve_class_or_fn(name, registered_name, module, obj_type, full_config, custom_objects)
#     800     if obj is not None:
#     801         return obj
# --> 803 raise TypeError(
#     804     f"Could not locate {obj_type} '{name}'. "
#     805     "Make sure custom classes are decorated with "
#     806     "`@keras.saving.register_keras_serializable()`. "
#     807     f"Full object config: {full_config}"
#     808 )
#
# TypeError: Could not locate function 'mse'. Make sure custom classes are decorated with `@keras.saving.register_keras_serializable()`. Full object config: {'module': 'keras.metrics', 'class_name': 'function', 'config': 'mse', 'registered_name': 'mse'}

# %%
new_model.summary()
